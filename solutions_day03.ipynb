# %% [markdown]
# # Day 3 - Model Calibration

# %%
# Import libraries
import numpy as np
import matplotlib.pyplot as plt
import emcee
import corner
from scipy.integrate import odeint
from scipy.optimize import minimize
from IPython.display import display, Math
from scipy.optimize import Bounds

# %% [markdown]
# ## Defining the model
# Let N be the number of tumor cells and assume that this number can increase with a growth rate of $r$ cells/hour until it reaches the environmental carrying capacity of $K$ cells. With these assumptions, the mathematical model is:
# \begin{equation}
# \frac{dN}{dt}=rN\left(1-\frac{N}{K}\right),
# \end{equation}
#
# - $\boldsymbol{\theta}$: vector of model parameters, $\boldsymbol{\theta}=(r,K)$;
# - $r$: tumor growth rate;
# - $K$: environmental carrying capacity;
# - $\boldsymbol{Y}(\boldsymbol{\theta})$: model prediction;

# %%
# Let y be the vector of outputs, t the time, and theta the vector of parameters
def control_tumor(y, t, theta):
    return theta[0] * y[0] * (1.0 - y[0] / theta[1])

# %% [markdown]
# ## Generating the data
# We will generate the in silico data using the true model and adding a random perturbation

# %%
# Define time interval, parameter value, and initial condition
times = np.arange(0,50,1)
true_r = 0.25
true_K = 60
true_ic = 1
# Solving the ODE model
y = odeint(control_tumor, t=times, y0=true_ic, args=tuple([[true_r,true_K]]))

# %%
#Adding perturbation
true_sigma = 3.6
np.random.seed(2021) # For reproducibility
yobs = np.random.normal(y,true_sigma)
yobs[yobs < 0] = 0

# %%
# Plotting the true and observed data
fig, ax = plt.subplots(dpi=120)
plt.plot(times, y, label='True data', color='black',linewidth=2.0)
plt.scatter(times, yobs, label='Measured data', color='red')
plt.legend()
plt.xlabel('Time (hours)')
plt.ylabel('Cell number');
#plt.savefig("just_data.pdf")
plt.show()

# %% [markdown]
# ## Maximum likelihood estimation
#
# Find $\hat{\boldsymbol{\theta}}\in\Theta$, where $\Theta$ is the parameter space, that maximize the likelihood.
#
# It is customary to work with the more manageable log-likelihood function.
#
# \begin{align*}
# \hat{\boldsymbol{\theta}}&=\underset{\boldsymbol{\theta}\in\Theta}{\text{argmax}}[\log\pi(\boldsymbol{D}|\boldsymbol{\theta})];\\
# &=\underset{\boldsymbol{\theta}\in\Theta}{\text{argmax}}\left[-\frac{N_t}{2}\log(2\pi)-\frac{N_t}{2}\log(\sigma^2)-\sum_{i=1}^{N_t}\frac{1}{2}\frac{(D_{i}-Y_i(\boldsymbol{\theta}))^2}{2\sigma^2}\right].
# \end{align*}

# %%
def log_likelihood(theta, times, y):
    cal_r, cal_K, cal_sigma = theta
    model = odeint(control_tumor, t=times, y0=y[0], args=tuple([[cal_r,cal_K]]))
    variance = cal_sigma*cal_sigma
    return -0.5 * np.sum((y - model) ** 2 / variance + np.log(2*np.pi) + np.log(variance))

# %%
nll = lambda *args: -log_likelihood(*args)
initial = np.array([0.4, 50.0, 0.3])+ 0.1 * np.random.randn(3)
bounds = Bounds([0.0, 10.0, 0.1], [1.0, 120.0, 50.0])
soln = minimize(nll, initial, args=(times, yobs), bounds=bounds)
ml_r, ml_K, ml_sigma = soln.x

print("Maximum likelihood estimates:")
print("Growth rate = %f" % ml_r)
print("Carrying capacity = %f" % ml_K)
print("Standard deviation = %f" % ml_sigma)

error_r=100*abs(ml_r-true_r)/true_r
error_K=100*abs(ml_K-true_K)/true_K
error_sigma=100*abs(ml_sigma-true_sigma)/true_sigma

print("Growth rate %% error = %f" % error_r)
print("Carrying capacity %% error = %f" % error_K)
print("Standard deviation %% error = %f" % error_sigma)
# Out:
# Maximum likelihood estimates:
# Growth rate = 0.138938
# Carrying capacity = 63.533098
# Standard deviation = 6.289244
# Growth rate % error = 44.424809
# Carrying capacity % error = 5.888497
# Standard deviation % error = 74.701226

# %%
y_ml = odeint(control_tumor, t=times, y0=yobs[0], args=tuple([[ml_r,ml_K]]))
fig, ax = plt.subplots(dpi=120)
plt.plot(times, y_ml, label='Calibrated model', linestyle='dashed', color='blue',linewidth=2.0)
plt.plot(times, y, label='True data', color='black', alpha=0.75,linewidth=2.0)
plt.scatter(times, yobs, label='Measured data', color='red')
plt.legend()
plt.xlabel('Time (hours)')
plt.ylabel('Cell number');
#plt.savefig("ml_fit.pdf")
plt.show()

# %%
def log_likelihood_ic(theta, times, y):
    cal_r, cal_K, cal_sigma, cal_ic = theta
    model = odeint(control_tumor, t=times, y0=cal_ic, args=tuple([[cal_r,cal_K]]))
    variance = cal_sigma*cal_sigma
    return -0.5 * np.sum((y - model) ** 2 / variance + np.log(2*np.pi) + np.log(variance))

# %%
nll = lambda *args: -log_likelihood_ic(*args)
initial = np.array([0.4, 50.0, 0.3, 5.0])+ 0.1 * np.random.randn(4)
bounds = Bounds([0.0, 10.0, 0.1, 0.1], [1.0, 120.0, 50.0, 20.0])
soln = minimize(nll, initial, args=(times, yobs), bounds=bounds)
ml_r, ml_K, ml_sigma, ml_ic = soln.x

print("Maximum likelihood estimates:")
print("Growth rate = %f" % ml_r)
print("Carrying capacity = %f" % ml_K)
print("Standard deviation = %f" % ml_sigma)
print("Initial condition = %f" % ml_ic)

error_r=100*abs(ml_r-true_r)/true_r
error_K=100*abs(ml_K-true_K)/true_K
error_sigma=100*abs(ml_sigma-true_sigma)/true_sigma
error_ic=100*abs(ml_ic-true_ic)/true_ic

print("Growth rate %% error = %f" % error_r)
print("Carrying capacity %% error = %f" % error_K)
print("Standard deviation %% error = %f" % error_sigma)
print("Initial condition %% error = %f" % error_ic)
# Out:
# Maximum likelihood estimates:
# Growth rate = 0.268103
# Carrying capacity = 60.229658
# Standard deviation = 3.525988
# Initial condition = 0.741901
# Growth rate % error = 7.241038
# Carrying capacity % error = 0.382763
# Standard deviation % error = 2.055878
# Initial condition % error = 25.809893

# %%
y_ml = odeint(control_tumor, t=times, y0=ml_ic, args=tuple([[ml_r,ml_K]]))
fig, ax = plt.subplots(dpi=120)
plt.plot(times, y_ml, label='Calibrated model', linestyle='dashed', color='blue',linewidth=2.0)
plt.plot(times, y, label='True data', color='black', alpha=0.75,linewidth=2.0)
plt.scatter(times, yobs, label='Measured data', color='red')
plt.legend()
plt.xlabel('Time (hours)')
plt.ylabel('Cell number');
#plt.savefig("ml_fit.pdf")
plt.show()

# %% [markdown]
# ## Bayesian approach
# Given events A and B:
# \begin{align*}
# P(A,B)&=P(A|B)P(B);\\
# P(A,B)&=P(B,A);\\
# P(B,A)&=P(B|A)P(A);\\
# P(A|B)P(B)&=P(B|A)P(A);\\
# P(A|B)&=\frac{P(B|A)P(A)}{P(B)};
# \end{align*}
#
# Converting to probability densities $\pi$, if $A$ represents the parameter $\boldsymbol{\theta}$ of a model, and $B$ the observational data $\boldsymbol{D}$:
# \begin{align*}
# \underbrace{\pi(\boldsymbol{\theta}|\boldsymbol{D})}_{\text{posterior}}&=\frac{\overbrace{\pi(\boldsymbol{D}|\boldsymbol{\theta})}^{\text{likelihood}}\overbrace{\pi(\boldsymbol{\theta})}^{\text{prior}}}{\underbrace{\pi(\boldsymbol{D})}_{\text{evidence}}};\qquad \pi(\boldsymbol{D})=\int_\Theta\pi(\boldsymbol{D}|\boldsymbol{\theta})\pi(\boldsymbol{\theta})\, \text{d}\theta\\
# \pi(\boldsymbol{\theta}|\boldsymbol{D})&\propto\pi(\boldsymbol{D}|\boldsymbol{\theta})\pi(\boldsymbol{\theta});\\
# \log\pi(\boldsymbol{\theta}|\boldsymbol{D})&\propto\log\pi(\boldsymbol{D}|\boldsymbol{\theta})+\log\pi(\boldsymbol{\theta});
# \end{align*}

# %%
def log_prior(theta):
    cal_r, cal_K, cal_sigma, cal_ic = theta
    if 0.0 < cal_r < 1.0 and 10.0 < cal_K < 120.0 and 0.1 < cal_sigma < 50.0 and 0.1 < cal_ic < 20.0:
        return 0.0
    return -np.inf

# %%
def log_probability(theta, times, y):
    lp = log_prior(theta)
    if not np.isfinite(lp):
        return -np.inf
    return lp + log_likelihood_ic(theta, times, y)

# %%
mean_par = np.array([0.4, 50.0, 0.3, 10.0])
pos = mean_par + 1e-2 * np.random.randn(10,4)

# %%
nwalkers, ndim = pos.shape
sampler = emcee.EnsembleSampler(nwalkers, ndim, log_probability, args=(times, yobs))
sampler.run_mcmc(pos, 12500, progress=True);
# Out:
# 100%|██████████| 12500/12500 [00:51<00:00, 241.13it/s]

# %%
fig, axes = plt.subplots(4, figsize=(10, 7), sharex=True)
samples = sampler.get_chain()
labels = ["Growth rate", "Carrying Capacity", "Standard deviation", "Initial condition"]
for i in range(ndim):
    ax = axes[i]
    ax.plot(samples[:, :, i], "k", alpha=0.3)
    ax.set_xlim(0, len(samples))
    ax.set_ylabel(labels[i])
    ax.yaxis.set_label_coords(-0.1, 0.5)

axes[-1].set_xlabel("step number");

# %%
tau = sampler.get_autocorr_time()
print(tau)
# Out:
# [ 71.55158338  43.16679644  40.56768278 150.95704435]

# %%
flat_samples = sampler.get_chain(discard=450, flat=True)
print(flat_samples.shape)
# Out:
# (120500, 4)

# %%
fig = corner.corner(flat_samples, labels=labels, truths=[true_r, true_K, true_sigma, true_ic]);

# %%
fig, ax = plt.subplots(dpi=120)
inds = np.random.randint(len(flat_samples), size=100)
for ind in inds:
    sample = flat_samples[ind]
    y_sp = odeint(control_tumor, t=times, y0=sample[3], args=tuple([[sample[0],sample[1]]]))
    plt.plot(times, y_sp, 'blue', alpha=0.5)
plt.plot(times, y_sp, label='Calibrated model', color='blue', alpha=0.5)
plt.scatter(times, yobs, zorder=100, label='Measured data', color='red')
plt.legend()
plt.xlabel('Time (hours)')
plt.ylabel('Cell number');
#plt.savefig("bc_fit.pdf")
plt.show()

# %%
for i in range(ndim):
    mcmc = np.percentile(flat_samples[:, i], [16, 50, 84])
    q = np.diff(mcmc)
    txt = "\mathrm{{{3}}} = {0:.3f}_{{-{1:.3f}}}^{{{2:.3f}}}"
    txt = txt.format(mcmc[1], q[0], q[1], labels[i])
    display(Math(txt))
# Out:
# $\displaystyle \mathrm{Growth rate} = 0.265_{-0.019}^{0.021}$
# $\displaystyle \mathrm{Carrying Capacity} = 60.251_{-0.824}^{0.834}$
# $\displaystyle \mathrm{Standard deviation} = 3.697_{-0.354}^{0.421}$
# $\displaystyle \mathrm{Initial condition} = 0.779_{-0.231}^{0.284}$

# %% [markdown]
# # Exercise
# Let C be the drug concentration (ng/mL) and assume that: it is consumed by the tumor by a rate $g$. The number of cells will decrease proportionally to the drug concentration at a rate $f$. With these assumptions, the mathematical model is:
# \begin{align}
# \frac{dN}{dt}&=rN\left(1-\frac{N}{K}\right)-fNC,\\
# \frac{dC}{dt}&=-gNC.
# \end{align}
#
# - $r$: tumor growth rate;
# - $K$: environmental carrying capacity;
# - $f$: tumor death rate due to the drug
# - $g$: drug consumption rate
# - $\theta=(r,K,f,a,b,g)$

# %%
#theta = (r,K,f,,g)
def treated_tumor(y, t, theta):
    tumor=theta[0] * y[0] * (1.0 - y[0] / theta[1])-theta[2]*y[0]*y[1]
    drug=-theta[3]*y[0]*y[1]
    return [tumor,drug]

# %% [markdown]
# ## Generating the data
# We will generate the in silico data using the true model and adding a random perturbation

# %%
# Define time interval, parameter value, and initial condition
times = np.arange(0,50,0.5)
r = 0.25
K = 60
f = 0.1
g = 0.2
tumor_ic = 1
drug_ic = 5
# Solving the ODE model
y = odeint(treated_tumor, t=times, y0=[tumor_ic,drug_ic], args=tuple([[r,K,f,g]]))

# %%
#Adding perturbation
true_sigmaT = 3.6
np.random.seed(2021) # For reproducibility
yobs = np.copy(y)
yobs[:,0] = np.random.normal(y[:,0],true_sigmaT)
true_sigmaD = 0.2
yobs[:,1] = np.random.normal(y[:,1],true_sigmaD)
yobs[yobs < 0] = 0

# %%
# Plotting the true and observed data
fig, ax = plt.subplots(dpi=120)
plt.plot(times, y[:,0], label='True data', color='black',linewidth=2.0)
plt.scatter(times, yobs[:,0], label='Measured data', color='red')
plt.legend()
plt.xlabel('Time (hours)')
plt.ylabel('Cell number');
#plt.savefig("just_data.pdf")
plt.show()

# %%
# Plotting the drug solution
fig, ax = plt.subplots(dpi=120)
plt.plot(times, y[:,1], label='True data', color='black',linewidth=2.0)
plt.scatter(times, yobs[:,1], label='Measured data', color='red')
plt.legend()
plt.xlabel('Time (hours)')
plt.ylabel('Drug Concentration');
#plt.savefig("just_data.pdf")
plt.show()

# %% [markdown]
# ## Assumptions
# The values of r, K, $\sigma_T$ and tumor initial condition are given as
#
# r = 0.265
#
# K = 60.251
#
# $\sigma_T$ = 3.697
#
# tumor initial condition = 0.779
#
# Calibrate
#
# f, g, $\sigma_D$, and drug initial condition

# %% [markdown]
# ## Maximum likelihood estimation
#
# Find $\hat{\boldsymbol{\theta}}\in\Theta$, where $\Theta$ is the parameter space, that maximize the likelihood.
#
# It is customary to work with the more manageable log-likelihood function.
#
# \begin{align*}
# \hat{\boldsymbol{\theta}}&=\underset{\boldsymbol{\theta}\in\Theta}{\text{argmax}}[\log\pi(\boldsymbol{D}|\boldsymbol{\theta})];\\
# &=\underset{\boldsymbol{\theta}\in\Theta}{\text{argmax}}\left[-\frac{N_t}{2}\log(2\pi)-\frac{N_t}{2}\log(\sigma^2)-\sum_{i=1}^{N_t}\frac{1}{2}\frac{(D_{i}-Y_i(\boldsymbol{\theta}))^2}{2\sigma^2}\right].
# \end{align*}

# %%
def log_likelihood_ic(theta, times, y, r, k, sigmaT, icT):
    cal_f, cal_g, cal_sigmaD, cal_icD = theta
    model = odeint(treated_tumor, t=times, y0=[icT,cal_icD], args=tuple([[r,K,cal_f,cal_g]]))
    varianceT = sigmaT**2
    varianceD = cal_sigmaD**2
    logT = -0.5 * np.sum((y[:,0] - model[:,0]) ** 2 / varianceT + np.log(2*np.pi) + np.log(varianceT))
    logD = -0.5 * np.sum((y[:,1] - model[:,1]) ** 2 / varianceD + np.log(2*np.pi) + np.log(varianceD))
    return logT+logD

# %%
nll = lambda *args: -log_likelihood_ic(*args)

initial = np.array([0.15, 0.15, 0.3, 5.0])+ 0.1 * np.random.randn(4)

bounds = Bounds([0.01, 0.01, 0.1, 4.0], [0.3, 0.3, 2.0, 6.0])

# %%
soln = minimize(nll, initial, args=(times, yobs, 0.265, 60.251, 3.697, 0.779), bounds=bounds)

# %%
ml_f, ml_g, ml_sigmaD, ml_icD = soln.x

print("Maximum likelihood estimates:")
print("Tumor death rate due to the drug = %f" % ml_f)
print("Drug consumption rate = %f" % ml_g)
print("Standard deviation (drug) = %f" % ml_sigmaD)
print("Initial condition (drug) = %f" % ml_icD)

error_f=100*abs(ml_f-f)/f
error_g=100*abs(ml_g-g)/g
error_sigmaD=100*abs(ml_sigmaD-true_sigmaD)/true_sigmaD
error_icD=100*abs(ml_icD-drug_ic)/drug_ic

print("Tumor death rate due to the drug %% error = %f" % error_r)
print("Drug consumption rate %% error = %f" % error_g)
print("Standard deviation %% error (drug) = %f" % error_sigmaD)
print("Initial condition %% error (drug) = %f" % error_icD)
# Out:
# Maximum likelihood estimates:
# Tumor death rate due to the drug = 0.103449
# Drug consumption rate = 0.241802
# Standard deviation (drug) = 0.146135
# Initial condition (drug) = 4.934715
# Tumor death rate due to the drug % error = 7.241038
# Drug consumption rate % error = 20.901235
# Standard deviation % error (drug) = 26.932628
# Initial condition % error (drug) = 1.305703

# %%
y_ml = odeint(treated_tumor, t=times, y0=[0.779,ml_icD], args=tuple([[0.265,60.251,ml_f,ml_g]]))
fig, ax = plt.subplots(dpi=120)
plt.plot(times, y_ml[:,1], label='Calibrated model', linestyle='dashed', color='blue',linewidth=2.0)
plt.plot(times, y[:,1], label='True data', color='black', alpha=0.75,linewidth=2.0)
plt.scatter(times, yobs[:,1], label='Measured data', color='red')
plt.legend()
plt.xlabel('Time (hours)')
plt.ylabel('Drug Concentration');
#plt.savefig("ml_fit.pdf")
plt.show()

# %%
fig, ax = plt.subplots(dpi=120)
plt.plot(times, y_ml[:,0], label='Calibrated model', linestyle='dashed', color='blue',linewidth=2.0)
plt.plot(times, y[:,0], label='True data', color='black', alpha=0.75,linewidth=2.0)
plt.scatter(times, yobs[:,0], label='Measured data', color='red')
plt.legend()
plt.xlabel('Time (hours)')
plt.ylabel('Cell number');
#plt.savefig("ml_fit.pdf")
plt.show()

# %% [markdown]
# ## Bayesian approach
# Given events A and B:
# \begin{align*}
# P(A,B)&=P(A|B)P(B);\\
# P(A,B)&=P(B,A);\\
# P(B,A)&=P(B|A)P(A);\\
# P(A|B)P(B)&=P(B|A)P(A);\\
# P(A|B)&=\frac{P(B|A)P(A)}{P(B)};
# \end{align*}
#
# Converting to probability densities $\pi$, if $A$ represents the parameter $\boldsymbol{\theta}$ of a model, and $B$ the observational data $\boldsymbol{D}$:
# \begin{align*}
# \underbrace{\pi(\boldsymbol{\theta}|\boldsymbol{D})}_{\text{posterior}}&=\frac{\overbrace{\pi(\boldsymbol{D}|\boldsymbol{\theta})}^{\text{likelihood}}\overbrace{\pi(\boldsymbol{\theta})}^{\text{prior}}}{\underbrace{\pi(\boldsymbol{D})}_{\text{evidence}}};\qquad \pi(\boldsymbol{D})=\int_\Theta\pi(\boldsymbol{D}|\boldsymbol{\theta})\pi(\boldsymbol{\theta})\, \text{d}\theta\\
# \pi(\boldsymbol{\theta}|\boldsymbol{D})&\propto\pi(\boldsymbol{D}|\boldsymbol{\theta})\pi(\boldsymbol{\theta});\\
# \log\pi(\boldsymbol{\theta}|\boldsymbol{D})&\propto\log\pi(\boldsymbol{D}|\boldsymbol{\theta})+\log\pi(\boldsymbol{\theta});
# \end{align*}

# %%
def log_prior(theta):
    cal_f, cal_g, cal_sigmaD, cal_icD = theta
    if 0.01 < cal_f < 0.25 and 0.01 < cal_g < 0.4 and 0.1 < cal_sigmaD < 2.0 and 4.5 < cal_icD < 5.5:
        return 0.0
    return -np.inf

# %%
def log_probability(theta, times, y, r, k, sigmaT, icT):
    lp = log_prior(theta)
    if not np.isfinite(lp):
        return -np.inf
    return lp + log_likelihood_ic(theta, times, y, r, k, sigmaT, icT)

# %%
mean_par = np.array([0.15, 0.15, 0.3, 5.0])
pos = mean_par + 1e-2 * np.random.randn(20,4)

# %%
nwalkers, ndim = pos.shape
sampler = emcee.EnsembleSampler(nwalkers, ndim, log_probability, args=(times, yobs, 0.265, 60.251, 3.697, 0.779))
sampler.run_mcmc(pos, 13000, progress=True);
# Out:
# 100%|██████████| 13000/13000 [08:39<00:00, 25.03it/s]

# %%
fig, axes = plt.subplots(4, figsize=(10, 7), sharex=True)
samples = sampler.get_chain()
labels = ["Death rate", "Drug consumption", "Standard deviation", "Initial condition"]
for i in range(ndim):
    ax = axes[i]
    ax.plot(samples[:, :, i], "k", alpha=0.3)
    ax.set_xlim(0, len(samples))
    ax.set_ylabel(labels[i])
    ax.yaxis.set_label_coords(-0.1, 0.5)

axes[-1].set_xlabel("step number");

# %%
tau = sampler.get_autocorr_time()
print(tau)
# Out:
# [30.3504263  53.04429153 86.44580923 47.46371464]

# %%
flat_samples = sampler.get_chain(discard=450, flat=True)
print(flat_samples.shape)
# Out:
# (251000, 4)

# %%
fig = corner.corner(flat_samples, labels=labels, truths=[true_r, true_K, true_sigma, true_ic]);

# %%
fig, ax = plt.subplots(dpi=120)
inds = np.random.randint(len(flat_samples), size=100)
for ind in inds:
    sample = flat_samples[ind]
    y_sp = odeint(treated_tumor, t=times, y0=[0.779,sample[3]], args=tuple([[0.265,60.251,sample[0],sample[1]]]))
    plt.plot(times, y_sp[:,0], 'blue', alpha=0.5)
plt.plot(times, y_sp[:,0], label='Calibrated model', color='blue', alpha=0.5)
plt.scatter(times, yobs[:,0], zorder=100, label='Measured data', color='red')
plt.legend()
plt.xlabel('Time (hours)')
plt.ylabel('Cell number');
#plt.savefig("bc_fit.pdf")
plt.show()

# %%
fig, ax = plt.subplots(dpi=120)
inds = np.random.randint(len(flat_samples), size=100)
for ind in inds:
    sample = flat_samples[ind]
    y_sp = odeint(treated_tumor, t=times, y0=[0.779,sample[3]], args=tuple([[0.265,60.251,sample[0],sample[1]]]))
    plt.plot(times, y_sp[:,1], 'blue', alpha=0.5)
plt.plot(times, y_sp[:,1], label='Calibrated model', color='blue', alpha=0.5)
plt.scatter(times, yobs[:,1], zorder=100, label='Measured data', color='red')
plt.legend()
plt.xlabel('Time (hours)')
plt.ylabel('Drug Concentration');
#plt.savefig("bc_fit.pdf")
plt.show()

# %%
for i in range(ndim):
    mcmc = np.percentile(flat_samples[:, i], [16, 50, 84])
    q = np.diff(mcmc)
    txt = "\mathrm{{{3}}} = {0:.3f}_{{-{1:.3f}}}^{{{2:.3f}}}"
    txt = txt.format(mcmc[1], q[0], q[1], labels[i])
    display(Math(txt))
# Out:
# $\displaystyle \mathrm{Death rate} = 0.103_{-0.002}^{0.002}$
# $\displaystyle \mathrm{Drug consumption} = 0.242_{-0.012}^{0.012}$
# $\displaystyle \mathrm{Standard deviation} = 0.149_{-0.010}^{0.011}$
# $\displaystyle \mathrm{Initial condition} = 4.938_{-0.088}^{0.091}$
